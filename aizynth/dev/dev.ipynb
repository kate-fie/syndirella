# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/dev/uspto_rxn_insight.gzip')
df
# Out:
#                                                   REACTION  \
# index
# 0                    CCS(=O)(=O)Cl.OCCBr>>CCS(=O)(=O)OCCBr
# 1                    CS(=O)(=O)Cl.OCCCBr>>CS(=O)(=O)OCCCBr
# 2            CC(C)CS(=O)(=O)Cl.OCCCl>>CC(C)CS(=O)(=O)OCCCl
# 3                    CCS(=O)(=O)Cl.OCCBr>>CCS(=O)(=O)OCCBr
# 4                    CS(=O)(=O)Cl.OCCCBr>>CS(=O)(=O)OCCCBr
# ...                                                    ...
# 1779996  CCOC(=O)c1nc(-c2ccc(N)cc2)nc(N2CCOCC2)c1OCC.Nc...
# 1779997  CCOC(=O)c1nc(-c2ccc(NC(=O)Nc3ccc(C(=O)O)cc3)cc...
# 1779998  COc1cnc(Cl)nc1N1CCOCC1.O=[N+]([O-])c1cccc(B(O)...
# 1779999  CC1(C)OB(c2ccc(N)c([N+](=O)[O-])c2)OC1(C)C.COc...
# 1780000  CC1(C)OB(c2ccc(N)cc2)OC1(C)C.CSc1c(Cl)nc(Cl)nc...
#
#                                            MAPPED_REACTION    SOLVENT  \
# index
# 0        Cl[S:3]([CH2:2][CH3:1])(=[O:4])=[O:5].[OH:6][C...  CCN(CC)CC
# 1        Cl[S:2]([CH3:1])(=[O:3])=[O:4].[OH:5][CH2:6][C...  CCN(CC)CC
# ...

# %%
len(df['REF'].unique())
# Out:
# 133746
