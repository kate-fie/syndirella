# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
df = pd.read_csv('//Users/kate_fieseler/PycharmProjects/retrievesynthesizable/D68EV3CPROA/elabs/1_step_1-1 2/MOLPORT_005-618-309_x1140_0A_x1594_0A/MOLPORT_005-618-309_x1140_0A_x1594_0A_1_step_19140.csv')
df
# Out:
#        reactant1_structuralScore  reactant1_mw  \
# 0                       1.000000       177.163
# 1                       0.337173       178.171
# 2                       1.000000       177.163
# 3                       0.337173       178.171
# 4                       1.000000       177.163
# ...                          ...           ...
# 19135                   0.226815       373.453
# 19136                   0.354782       387.480
# 19137                   0.354782       387.480
# 19138                   0.226815       373.453
# 19139                   0.354782       387.480
#
#                                            reactant1_smi  \
# 0                                   O=C(O)Cn1nnc2ccccc21
# 1                             O=C(O)C[n+]1[nH]nc2ccccc21
# 2                                   O=C(O)Cn1nnc2ccccc21
# 3                             O=C(O)C[n+]1[nH]nc2ccccc21
# 4                                   O=C(O)Cn1nnc2ccccc21
# ...

# %%
df_out = pd.read_csv('/Users/kate_fieseler/PycharmProjects/retrievesynthesizable/D68EV3CPROA/elabs/1_step_1-1 2/MOLPORT_005-618-309_x1140_0A_x1594_0A/output.csv', index_col=0)
df_out
# Out:
#                                                   smiles         error  \
# 0                  O=C(Cn1nnc2ccccc21)NCCc1ccc2c(c1)OCO2           NaN
# 1            O=C(C[n+]1[nH]nc2ccccc21)NCCc1ccc2c(c1)OCO2           NaN
# 2               CN(CCc1ccc2c(c1)OCO2)C(=O)Cn1nnc2ccccc21           NaN
# 3         O=C(C[n+]1[nH]nc2ccccc21)N1CCc2cc3c(cc2C1)OCO3           NaN
# 4           C[C@H](CNC(=O)Cn1nnc2ccccc21)c1ccc2c(c1)OCO2           NaN
# ...                                                  ...           ...
# 19135  Cc1nc(SCCNC(=O)Cc2ccc3c(c2)OCO3)n(C(=O)Cc2ccc3...           NaN
# 19136                                                NaN  TimeoutError
# 19137  Cc1nc(SCCNC(=O)Cc2ccc3c(c2)OCO3)n(C(=O)Cc2ccc3...           NaN
# 19138                                                NaN  TimeoutError
# 19139                                                NaN  TimeoutError
#
#              ∆∆G  ∆G_bound  ∆G_unbound   comRMSD  N_constrained_atoms  \
# ...

# %%
df_full = df.merge(df_out, on='smiles', how='left')
df_full
# Out:
#        reactant1_structuralScore  reactant1_mw  \
# 0                       1.000000       177.163
# 1                       0.337173       178.171
# 2                       1.000000       177.163
# 3                       0.337173       178.171
# 4                       1.000000       177.163
# ...                          ...           ...
# 19135                   0.226815       373.453
# 19136                   0.354782       387.480
# 19137                   0.354782       387.480
# 19138                   0.226815       373.453
# 19139                   0.354782       387.480
#
#                                            reactant1_smi  \
# 0                                   O=C(O)Cn1nnc2ccccc21
# 1                             O=C(O)C[n+]1[nH]nc2ccccc21
# 2                                   O=C(O)Cn1nnc2ccccc21
# 3                             O=C(O)C[n+]1[nH]nc2ccccc21
# 4                                   O=C(O)Cn1nnc2ccccc21
# ...

# %%
# make histogram of the number of acceptable compounds and num atom difference
accept_df = df_full[df_full['outcome'] == 'acceptable']
accept_df
# Out:
#        reactant1_structuralScore  reactant1_mw  \
# 9                       1.000000       177.163
# 10                      0.337173       178.171
# 13                      0.337173       178.171
# 16                      1.000000       177.163
# 23                      1.000000       177.163
# ...                          ...           ...
# 19121                   0.354782       387.480
# 19129                   0.354782       387.480
# 19130                   0.226815       373.453
# 19135                   0.226815       373.453
# 19137                   0.354782       387.480
#
#                                            reactant1_smi  \
# 9                                   O=C(O)Cn1nnc2ccccc21
# 10                            O=C(O)C[n+]1[nH]nc2ccccc21
# 13                            O=C(O)C[n+]1[nH]nc2ccccc21
# 16                                  O=C(O)Cn1nnc2ccccc21
# 23                                  O=C(O)Cn1nnc2ccccc21
# ...

# %%
ax = accept_df['num_atom_difference'].hist(bins=10)
ax.set_xlabel('Number of atoms difference to base compound')
# Annotate each bin
for rect in ax.patches:
    height = rect.get_height()
    ax.annotate(f'{int(height)}', (rect.get_x() + rect.get_width() / 2, height), 
                ha='center', va='bottom')

# %%
# How many molecules have less than 20 atom difference?
len(accept_df)
# Out:
# 1376

# %%
len(df[df['num_atom_difference'] < 15]) / len(df) * 100
# Out:
# 53.74608150470219

# %%
len(accept_df[accept_df['num_atom_difference'] < 15])
# Out:
# 1284

# %%
1284/1376
# Out:
# 0.9331395348837209

# %%
len(df)
# Out:
# 19140
