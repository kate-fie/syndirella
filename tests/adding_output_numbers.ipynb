# %%
import datetime
import os
import pandas as pd

# %% [markdown]
# # ADDING OUTPUT NUMBERS TO FILENAME

# %%
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/retrievesynthesizable/D68EV3CPROA/routes_data/D68EV3CPROA_enumeration_oct10_first_route_2_step_FORWARD_2nd_step_OUTPUT.csv', index_col=0)
df
# Out:
#                                                     num_steps  \
# smiles
# Cc1cc2c(cc1NC(=O)NCCc1nnc3ccccn13)OCO2                      1
# O=C(NCc1nnc2ccccn12)c1ccc2c(c1)OCO2                         1
# O=S(=O)(CCC1CC1)NCc1nnc2ccccn12                             1
# C[C@@H](Sc1nnc2ccc(C(F)(F)F)cn12)C(=O)Nc1ccc2c(...          1
# O=C(NCCc1nnc2ccccn12)c1c(F)ccc2c1OCO2                       1
# ...                                                       ...
# COC(=O)NCC(=O)N1CCC[C@H]1CNC(=O)[C@H]1CCCS1                 1
# COC(=O)N[C@H](C)C(=O)N1CC([C@H](C)NC(=O)CC2CCC2)C1          1
# COC(=O)NCC(=O)N1CCC(CCNC(=O)C2CCC2)CC1                      1
# CC[C@@H](NC(=O)OC(C)(C)C)C(=O)N1CCC(NC(=O)C2CCC...          1
# COC(=O)NCC(=O)N1[C@H]2CC[C@]1(CNC(=O)C1CCC1)CC2             1
#
#                                                         rxn_order_first_to_last  \
# smiles
# Cc1cc2c(cc1NC(=O)NCCc1nnc3ccccn13)OCO2              ['Sp3-sp2_Suzuki_coupling']
# ...

# %%
# Enumerate through the parent directory
parent_directory = '/Users/kate_fieseler/PycharmProjects/retrievesynthesizable/D68EV3CPROA/elabs/2_step'  # Update this path
suffix = '2_of_2.csv'
# Replace all colons with underscores
df['dir_name'] = df['dir_name'].str.replace(':', '_')
for root, dirs, files in os.walk(parent_directory):
    for directory in dirs:
        for index, row in df.iterrows():
            dir_names = eval(row['dir_name'])
            print(index)
            print(dir_names)
            if directory in dir_names:
                # If directory exists, go into the directory and find .csv
                csv_files = [f for f in os.listdir(os.path.join(root, directory)) if f.endswith(suffix)]
                for csv_file in csv_files:
                    try:
                        analog_number = int(csv_file.split('.')[0].split('_')[-4])  # Extract the integer
                        df.at[index, 'Analogs'] = analog_number
                        df.at[index, 'Done_Time'] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                    except ValueError:
                        pass
                break
# Out:
# Cc1cc2c(cc1NC(=O)NCCc1nnc3ccccn13)OCO2
# ['ENAMINE_Z1637917899_x1140_0A_x1594_0A']
# O=C(NCc1nnc2ccccn12)c1ccc2c(c1)OCO2
# ['MOLPORT_004-137-806_x1140_0A_x1594_0A']
# O=S(=O)(CCC1CC1)NCc1nnc2ccccn12
# ['ENAMINE_Z1530202140_x1140_0A_x1594_0A']
# C[C@@H](Sc1nnc2ccc(C(F)(F)F)cn12)C(=O)Nc1ccc2c(c1)OCO2
# ['MOLPORT_009-461-148_x1594_0A_x1140_0A', 'MOLPORT_009-461-148_x1594_0A_x1919_0A', 'MOLPORT_009-461-148_x1594_0A_x2021_0A']
# O=C(NCCc1nnc2ccccn12)c1c(F)ccc2c1OCO2
# ['ENAMINE_PV-001909292151_x1140_0A_x1594_0A']
# O=C(NCc1ccc2c(c1)OCO2)[C@H]1CCCN(c2nnc3ccccn23)C1
# ['MOLPORT_010-964-018_x1594_0A_x1140_0A']
# O=C(NCCc1nnc2ccccn12)NCc1ccc2c(c1)OCO2
# ['MOLPORT_009-308-595_x1140_0A_x1594_0A', 'MOLPORT_009-308-595_x1594_0A_x1140_0A', 'MOLPORT_009-308-595_x1594_0A_x1919_0A', 'MOLPORT_009-308-595_x1594_0A_x2021_0A']
# NC(=O)c1ccc(N2CCC[C@@H]2c2ccc3c(c2)OCO3)nc1
# ['ENAMINE_Z1225461273_x1498_0A_x1140_0A']
# O=C(NCCCc1nnc2ccccn12)c1ccc2c(c1)OCO2
# ['MOLPORT_008-314-423_x1140_0A_x1594_0A']
# ...

# %%
df
# Out:
#                                                     num_steps  \
# smiles
# Cc1cc2c(cc1NC(=O)NCCc1nnc3ccccn13)OCO2                      1
# O=C(NCc1nnc2ccccn12)c1ccc2c(c1)OCO2                         1
# O=S(=O)(CCC1CC1)NCc1nnc2ccccn12                             1
# C[C@@H](Sc1nnc2ccc(C(F)(F)F)cn12)C(=O)Nc1ccc2c(...          1
# O=C(NCCc1nnc2ccccn12)c1c(F)ccc2c1OCO2                       1
# ...                                                       ...
# COC(=O)NCC(=O)N1CCC[C@H]1CNC(=O)[C@H]1CCCS1                 1
# COC(=O)N[C@H](C)C(=O)N1CC([C@H](C)NC(=O)CC2CCC2)C1          1
# COC(=O)NCC(=O)N1CCC(CCNC(=O)C2CCC2)CC1                      1
# CC[C@@H](NC(=O)OC(C)(C)C)C(=O)N1CCC(NC(=O)C2CCC...          1
# COC(=O)NCC(=O)N1[C@H]2CC[C@]1(CNC(=O)C1CCC1)CC2             1
#
#                                                         rxn_order_first_to_last  \
# smiles
# Cc1cc2c(cc1NC(=O)NCCc1nnc3ccccn13)OCO2              ['Sp3-sp2_Suzuki_coupling']
# ...

# %%
df.to_csv('/Users/kate_fieseler/PycharmProjects/retrievesynthesizable/D68EV3CPROA/routes_data/D68EV3CPROA_enumeration_oct10_first_route_2_step_FORWARD_2nd_step_OUTPUT.csv')
