# %%
import pandas as pd

# %%
dfs = [
    '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/send/BHKVBKDDVLQZCR-UHFFFAOYSA-N_3ADBvA_to_hippo.pkl.gz',
    '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/send/GHOYNZDJCPMSBM-UHFFFAOYSA-N_4NaSrt_to_hippo.pkl.gz',
    '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/send/LXINEYASRREWNB-UHFFFAOYSA-N_oq22mH_to_hippo.pkl.gz',
    '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/send/UASLKFQKYXHLQJ-UHFFFAOYSA-N_Kct9up_to_hippo.pkl.gz',
    '/Users/kate_fieseler/PycharmProjects/EV-A71-2A-syndirella-run/placements_april8/to_jenna/send/BCPKNOZHZDDVQN-UHFFFAOYSA-N_3LdJjd_to_hippo.pkl.gz'
]
# Create a list to hold the first row of each DataFrame
rows = []

# Iterate over the list of file paths
for file_path in dfs:
    # Load each DataFrame
    df = pd.read_pickle(file_path)
    # Append the first row of the DataFrame to the list
    rows.append(df.iloc[0,:])

# Concatenate all the rows along axis 1 (column-wise)
master = pd.concat(rows, axis=1)

# %%
master = master.transpose()
master.reset_index(drop=True)
master
# Out:
#                  base_compound_smiles 1_reaction    1_r1_smiles  \
# 0   N#CCC(=O)Nc1cccc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 0   N#CCC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1  Amidation  O=C(O)C1CCCO1
# 0   Cn1ncc(NC(=O)CC#N)c1NC(=O)C1CCCO1  Amidation  O=C(O)C1CCCO1
# 0  N#CCC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F  Amidation  O=C(O)C1CCCO1
# 0  Cc1ccc(NC(=O)C2CCCO2)cc1NC(=O)CC#N  Amidation  O=C(O)C1CCCO1
#
#                    1_r2_smiles 1_r_previous_product  \
# 0   CC(C)(C)OC(=O)Nc1cccc(N)c1                 None
# 0   CC(C)(C)OC(=O)Nc1ccnc(N)c1                 None
# 0   Cn1ncc(NC(=O)OC(C)(C)C)c1N                 None
# 0  CC(C)(C)OC(=O)Nc1cc(N)ccc1F                 None
# 0  Cc1ccc(N)cc1NC(=O)OC(C)(C)C                 None
#
#                           1_product_smiles  \
# 0   CC(C)(C)OC(=O)Nc1cccc(NC(=O)C2CCCO2)c1
# 0   CC(C)(C)OC(=O)Nc1ccnc(NC(=O)C2CCCO2)c1
# 0   Cn1ncc(NC(=O)OC(C)(C)C)c1NC(=O)C1CCCO1
# 0  CC(C)(C)OC(=O)Nc1cc(NC(=O)C2CCCO2)ccc1F
# ...

# %%
# save
master.to_pickle('/Users/kate_fieseler/PycharmProjects/syndirella/syndirella/tests/vectors/5_bases_w_routes.pkl.gz')
