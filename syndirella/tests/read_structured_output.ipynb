# %% [markdown]
# # Read Structured Output Pickle File
#
# This notebook reads and displays the contents of the structured output pickle file.

# %%
import pickle
import gzip
import os
from pathlib import Path

# %%
# Define the path to the structured output file
file_path = "outputs/test_pipeline/VKQJXGLAYUFNNG-UHFFFAOYSA-N/VKQJXGLAYUFNNG-UHFFFAOYSA-N_ae81efb0b6cfb28c67318159ab501474_structured_output.pkl.gz"

# Check if file exists
if os.path.exists(file_path):
    print(f"File found: {file_path}")
    print(f"File size: {os.path.getsize(file_path)} bytes")
else:
    print(f"File not found: {file_path}")
    # Try alternative path
    alt_path = "../outputs/test_pipeline/VKQJXGLAYUFNNG-UHFFFAOYSA-N/VKQJXGLAYUFNNG-UHFFFAOYSA-N_ae81efb0b6cfb28c67318159ab501474_structured_output.pkl.gz"
    if os.path.exists(alt_path):
        print(f"Found at alternative path: {alt_path}")
        file_path = alt_path
    else:
        print(f"File not found at alternative path either: {alt_path}")
# Out:
# File found: outputs/test_pipeline/VKQJXGLAYUFNNG-UHFFFAOYSA-N/VKQJXGLAYUFNNG-UHFFFAOYSA-N_ae81efb0b6cfb28c67318159ab501474_structured_output.pkl.gz
# File size: 1612 bytes

# %%
import pandas as pd
df = pd.read_pickle(file_path)
df
# Out:
#                           scaffold_smiles 1_reaction  \
# 0   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 1   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 2   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 3   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 4   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 5   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 6   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 7   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 8   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 9   O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 10  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 11  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 12  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 13  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 14  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 15  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# 16  O=C(NC1CC(C(F)(F)F)C1)c1cc2ccsc2[nH]1  Amidation
# ...
