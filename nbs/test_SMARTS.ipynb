# %%
from rdkit import Chem

# %%
mol = Chem.MolFromSmiles('CNC(C)Cc1cc2cccc(B3OC(C)(C)C(C)(C)O3)c2[nH]1')
reactant_mol = Chem.MolFromSmarts('[#6X3:2]-[B](-[OX2])(-[OX2])')

# %%
mol

# %%
reactant_mol

# %%
mol.GetSubstructMatches(reactant_mol)
# Out:
# ((11, 12, 13, 20),)
