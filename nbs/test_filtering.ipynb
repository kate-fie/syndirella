# %%
from rdkit.Chem.FilterCatalog import *
import pandas as pd
from rdkit import Chem
import ast
# Out:
# /var/folders/sg/gb03t0zx5sz8vw2lxlghz1gr0000gn/T/ipykernel_56729/4033293344.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/syndirella/exps/original/extra/KFKUHRDIQZWKPK-UHFFFAOYSA-N_Sp2-sp2_Suzuki_coupling_r1_1of1.csv', index_col=0)
df
# Out:
#                           r1_smiles  \
# 0                    Br[12c]1ccccn1
# 1                     Oc1cccc(Br)n1
# 2                     Nc1cccc(Br)n1
# 3                     Bc1ccnc(Br)c1
# 4                     Fc1ccnc(Br)c1
# ...                             ...
# 2165     O=C(OCc1ccnc(Br)c1)c1cocn1
# 2166     O=C(OCc1ccc(Br)nc1)c1cscn1
# 2167     O=C(OCc1ccnc(Br)c1)c1csnn1
# 2168     O=C(OCc1ccc(Br)nc1)c1cnco1
# 2169  O=C1CC(C(=O)OCc2cccc(Br)n2)C1
#
#                                              r1_mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x14f41a040>
# 1     <rdkit.Chem.rdchem.Mol object at 0x14f41a580>
# 2     <rdkit.Chem.rdchem.Mol object at 0x14f41a5f0>
# 3     <rdkit.Chem.rdchem.Mol object at 0x14f41a6d0>
# 4     <rdkit.Chem.rdchem.Mol object at 0x14f41ac80>
# ...                                             ...
# 2165  <rdkit.Chem.rdchem.Mol object at 0x16c700580>
# 2166  <rdkit.Chem.rdchem.Mol object at 0x16c700740>
# ...

# %%
# Initialize FilterCatalogParams
params = FilterCatalogParams()
params.AddCatalog(FilterCatalogParams.FilterCatalogs.PAINS_A) # BRENK is same as Dundee I think
# Create the FilterCatalog
catalog = FilterCatalog(params)
for i in range(catalog.GetNumEntries()):
    entry = catalog.GetEntry(i)
    print(f"Entry {i}:")
    print("  Description:", entry.GetDescription())
# Out:
# Entry 0:
#   Description: ene_six_het_A(483)
# Entry 1:
#   Description: hzone_phenol_A(479)
# Entry 2:
#   Description: anil_di_alk_A(478)
# Entry 3:
#   Description: indol_3yl_alk(461)
# Entry 4:
#   Description: quinone_A(370)
# Entry 5:
#   Description: azo_A(324)
# Entry 6:
#   Description: imine_one_A(321)
# Entry 7:
#   Description: mannich_A(296)
# Entry 8:
#   Description: anil_di_alk_B(251)
# Entry 9:
#   Description: anil_di_alk_C(246)
# Entry 10:
#   Description: ene_rhod_A(235)
# Entry 11:
#   Description: hzone_phenol_B(215)
# Entry 12:
#   Description: ene_five_het_A(201)
# Entry 13:
#   Description: anil_di_alk_D(198)
# Entry 14:
#   Description: imine_one_isatin(189)
# Entry 15:
#   Description: anil_di_alk_E(186)

# %%
molecules = [Chem.MolFromSmiles(smi) for smi in df['r1_smiles']]
molecules
# Out:
# ...
#  ...]

# %%
# Filter molecules
filtered_molecules = []
flagged_molecules = []
for mol in molecules:
    if not catalog.HasMatch(mol):
        filtered_molecules.append(mol)
    else:
        flagged_molecules.append(mol)

# %%
flagged_molecules

# %%
# what about final product list
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/syndirella/exps/original/KFKUHRDIQZWKPK-UHFFFAOYSA-N_Sp2-sp2_Suzuki_coupling_products_1of1.csv', index_col=0)
df
# Out:
#                  r1_smiles                                         r1_mol  \
# 0           Br[12c]1ccccn1  <rdkit.Chem.rdchem.Mol object at 0x14f41a040>
# 1           Br[12c]1ccccn1  <rdkit.Chem.rdchem.Mol object at 0x14f41a040>
# 2            Brc1cc(I)ccn1  <rdkit.Chem.rdchem.Mol object at 0x14f41a4a0>
# 3            Nc1cccc(Br)n1  <rdkit.Chem.rdchem.Mol object at 0x14f41a5f0>
# 4            Oc1ccc(Br)nc1  <rdkit.Chem.rdchem.Mol object at 0x14f41af90>
# ...                    ...                                            ...
# 9995        Fc1c(S)ccnc1Br  <rdkit.Chem.rdchem.Mol object at 0x16c0434a0>
# 9996      Fc1cnc(Br)c(S)c1  <rdkit.Chem.rdchem.Mol object at 0x16c043580>
# 9997  [O-][n+]1cccc(F)c1Br  <rdkit.Chem.rdchem.Mol object at 0x16c043200>
# 9998        Fc1cc(S)cnc1Br  <rdkit.Chem.rdchem.Mol object at 0x16c043b30>
# 9999        Fc1cc(S)cnc1Br  <rdkit.Chem.rdchem.Mol object at 0x16c043b30>
#
#                              r2_smiles  \
# ...

# %%
molecules = [Chem.MolFromSmiles(smi) for smi in df['smiles']]

# %%
molecules
# Filter molecules
filtered_molecules = []
for mol in molecules:
    if not catalog.HasMatch(mol):
        filtered_molecules.append(mol)

# %%
filtered_molecules
# Out:
# ...
#  ...]

# %%
len(filtered_molecules)
# Out:
# 3456

# %%
# how many of products are still flagged by pains A from reactants?
df = pd.read_csv('/Users/kate_fieseler/PycharmProjects/syndirella/exps/painsA_noclust/KFKUHRDIQZWKPK-UHFFFAOYSA-N_Sp2-sp2_Suzuki_coupling_products_1of1.csv', index_col=0)
df
# Out:
#              r1_smiles                                         r1_mol  \
# 0       Br[12c]1ccccn1  <rdkit.Chem.rdchem.Mol object at 0x177e5b580>
# 1       Br[12c]1ccccn1  <rdkit.Chem.rdchem.Mol object at 0x177e5b580>
# 2          Sc1cccnc1Br  <rdkit.Chem.rdchem.Mol object at 0x177e5beb0>
# 3        Nc1cccc(Br)n1  <rdkit.Chem.rdchem.Mol object at 0x177e5b660>
# 4        Sc1ccc(Br)nc1  <rdkit.Chem.rdchem.Mol object at 0x177e5b820>
# ...                ...                                            ...
# 9995    Fc1cnc(Br)cc1F  <rdkit.Chem.rdchem.Mol object at 0x294101820>
# 9996  Fc1cnc(Br)c(S)c1  <rdkit.Chem.rdchem.Mol object at 0x294101ac0>
# 9997    Nc1cc(F)cnc1Br  <rdkit.Chem.rdchem.Mol object at 0x294100740>
# 9998  Fc1cnc(Br)c(S)c1  <rdkit.Chem.rdchem.Mol object at 0x294101ac0>
# 9999    Fc1cnc(Br)cc1S  <rdkit.Chem.rdchem.Mol object at 0x294101580>
#
#                              r2_smiles  \
# 0                OB(O)c1cccc2cc[nH]c12
# 1                Cn1ccc2cccc(B(O)O)c21
# ...

# %%
molecules = [Chem.MolFromSmiles(smiles) for smiles in df['smiles']]
molecules
# Out:
# ...
#  ...]

# %%
# Filter molecules
filtered_molecules = []
flagged_molecules = []
for mol in molecules:
    if not catalog.HasMatch(mol):
        filtered_molecules.append(mol)
    else:
        flagged_molecules.append(mol)

# %%
len(flagged_molecules)
# Out:
# 0
